# %% [markdown]
# <a href="https://colab.research.google.com/github/SanuliGehara/Test-Google-Collab/blob/main/tutorial1/Tutorial_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Week 1 Tutorial - Machine Learning

# %% [markdown]
# # **1. Getting Started** 🚀
#
#
# First we will try some simple python code to understand how this works. 😇 Then we will dive into more complex program to work with datasets.

# %%
print ("Hello world!")
print ("Welcome to Jupiter Notebooks")
# Out:
# Hello world!
# Welcome to Jupiter Notebooks

# %% [markdown]
# * Now since we are familiar with how to use jupiter notebooks, we will start working with data.
#
# * First step is to install **pandas** which is a data manipulations library in Python.

# %%
# !pip install pandas

# %% [markdown]
# * Through the **Pandas library**, data manipulation becomes easy. Hence, let’s understand Data Manipulation with Pandas in more detail.
#
# * We will also use the **Mall_Customers** dataset to show the syntax of these functions in the work.
#
# ### **1- Load your dataset in Colab with Pandas library:**
# Read CSV file using **pd.read_csv** and load data. You must import pandas as using pd for the shorthand.

# %%
# Import Pandas Library as pd
import pandas as pd

# Load dataset into a data_frame
data_frame = pd.read_csv('/content/Mall_Customers.csv')

# %% [markdown]
# ### **2- Accessing your dataset values:**
#
#  As part of data exploration, you can print the rows and columns of your dataset on the screen to see their values.
#
#  * By default, **data_frame.head()** displays the first five rows and **data_frame.tail()** displays the last five rows.
#
#  * If we want to get the **first ‘n’ number of rows,** then we use **data_frame.head(n)** is similar to the syntax used to print the **last n rows** of the data frame, **data_frame.tail(n)**.

# %%
# Display first 5 rows of Customer.csv
data_frame.head()
# Out:
#    CustomerID  Gender   Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male  19.0                15.0                     NaN
# 1           2    Male   NaN                15.0                    81.0
# 2           3  Female  20.0                16.0                     6.0
# 3           4  Female  23.0                 NaN                    77.0
# 4           5  Female   NaN                 NaN                    40.0

# %%
# Display Last 10 rows
data_frame.tail(10)
# Out:
#    CustomerID Gender   Age  Annual Income (k$)  Spending Score (1-100)
# 0           1   Male  19.0                15.0                     NaN
# 1           2   Male   NaN                15.0                    81.0

# %%
# Display first 2 rows
data_frame.head(2)
# Out:
#    CustomerID Gender   Age  Annual Income (k$)  Spending Score (1-100)
# 0           1   Male  19.0                15.0                     NaN
# 1           2   Male   NaN                15.0                    81.0

# %% [markdown]
# ### **3- Display the column names of the data_frame:**
#
# You can display them by applying the list() function with .columns. This will return a list of column in the data_frame.

# %%
#Display columns in data_frame
list(data_frame.columns)
# Out:
# ['CustomerID', 'Gender', 'Age', 'Annual Income (k$)', 'Spending Score (1-100)']

# %% [markdown]
# ### **4- Exploring data types of each column**
#
# Use **data_frame.info()** function to get a summary of data frame, including data type and count of not null values.

# %%
# List of data types
data_frame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   CustomerID              200 non-null    int64
#  1   Gender                  200 non-null    object
#  2   Age                     197 non-null    float64
#  3   Annual Income (k$)      198 non-null    float64
#  4   Spending Score (1-100)  199 non-null    float64
# dtypes: float64(3), int64(1), object(1)
# memory usage: 7.9+ KB

# %% [markdown]
# ### **5- Get summary of columns**
#
# In a dataset, their can be value errors and it is important to identify them. For that we can check descriptive stats of the dataset. The **describe()** function outputs descriptive statistics.
#
# * By default, for numeric data, the result will include **count, mean, std, min, and max, as well as lower, 50, and upper percentiles.**
#
# * For object data (e.g. categorical values), the result will include **count, unique, top, and freq.**

# %%
#Stats for numeric data
data_frame.describe()
# Out:
#        CustomerID         Age  Annual Income (k$)  Spending Score (1-100)
# count  200.000000  197.000000          198.000000              199.000000
# mean   100.500000   39.000000           61.005051               50.256281
# std     57.879185   14.002915           26.017857               25.876350
# min      1.000000   18.000000           15.000000                1.000000
# 25%     50.750000   29.000000           42.250000               34.500000
# 50%    100.500000   36.000000           62.000000               50.000000
# 75%    150.250000   49.000000           78.000000               73.000000
# max    200.000000   70.000000          137.000000               99.000000

# %%
# Object Stats
data_frame.describe(include=object)
# Out:
#         Gender
# count      200
# unique       2
# top     Female
# freq       112

# %% [markdown]
# ### **6- Dataset dimension:**
#
# Dataset dimension is number of rows and number of columns in the dataset. Normally rows are known as instances/data points and columns are known as features or variables. To find that we use **shape**.

# %%
# Num of Rows and Columns in Dataset
data_frame.shape
# Out:
# (200, 5)

# %% [markdown]
# ### **7- Find Missing data values:**
#
# There can be plenty of missiong values in a dataset. We get the missing (null) value count by using **isnull().sum()** functions.

# %%
# Missing Values Count
data_frame.isnull().sum()
# Out:
# CustomerID                0
# Gender                    0
# Age                       3
# Annual Income (k$)        2
# Spending Score (1-100)    1
# dtype: int64

# %% [markdown]
# To find the percentage of missing data values per variable, :**Divide it by length of data set and multiply by 100%**

# %%
# Missing Values Percentage
data_frame.isnull().sum()/len(data_frame)*100
# Out:
# CustomerID                0.0
# Gender                    0.0
# Age                       1.5
# Annual Income (k$)        1.0
# Spending Score (1-100)    0.5
# dtype: float64
